# %% [markdown]
# https://colab.research.google.com/notebook#create=true&language=r

# %%
installed.packages()
# Out:
#                Package        LibPath                       Version
# IRdisplay      IRdisplay      /usr/local/lib/R/site-library 0.7.0
# IRkernel       IRkernel       /usr/local/lib/R/site-library 1.1.1
# palmerpenguins palmerpenguins /usr/local/lib/R/site-library 0.1.0
# pbdZMQ         pbdZMQ         /usr/local/lib/R/site-library 0.3-3
# repr           repr           /usr/local/lib/R/site-library 1.1.0
# uuid           uuid           /usr/local/lib/R/site-library 0.1-4
# askpass        askpass        /usr/lib/R/site-library       1.1
# assertthat     assertthat     /usr/lib/R/site-library       0.2.1
# backports      backports      /usr/lib/R/site-library       1.1.9
# base64enc      base64enc      /usr/lib/R/site-library       0.1-3
# BH             BH             /usr/lib/R/site-library       1.72.0-3
# blob           blob           /usr/lib/R/site-library       1.2.1
# brew           brew           /usr/lib/R/site-library       1.0-6
# broom          broom          /usr/lib/R/site-library       0.7.0
# callr          callr          /usr/lib/R/site-library       3.4.4
# cellranger     cellranger     /usr/lib/R/site-library       1.1.0
# cli            cli            /usr/lib/R/site-library       2.0.2
# clipr          clipr          /usr/lib/R/site-library       0.7.0
# colorspace     colorspace     /usr/lib/R/site-library       1.4-1
# commonmark     commonmark     /usr/lib/R/site-library       1.7
# covr           covr           /usr/lib/R/site-library       3.5.0
# cpp11          cpp11          /usr/lib/R/site-library       0.2.1
# crayon         crayon         /usr/lib/R/site-library       1.3.4
# crosstalk      crosstalk      /usr/lib/R/site-library       1.1.0.1
# curl           curl           /usr/lib/R/site-library       4.2
# DBI            DBI            /usr/lib/R/site-library       1.1.0
# dbplyr         dbplyr         /usr/lib/R/site-library       1.4.4
# desc           desc           /usr/lib/R/site-library       1.2.0
# devtools       devtools       /usr/lib/R/site-library       2.3.1
# digest         digest         /usr/lib/R/site-library       0.6.25
# ⋮              ⋮              ⋮                             ⋮
# yaml           yaml           /usr/lib/R/site-library       2.2.1
# base           base           /usr/lib/R/library            3.6.3
# boot           boot           /usr/lib/R/library            1.3-25
# class          class          /usr/lib/R/library            7.3-17
# cluster        cluster        /usr/lib/R/library            2.1.0
# codetools      codetools      /usr/lib/R/library            0.2-16
# compiler       compiler       /usr/lib/R/library            3.6.3
# datasets       datasets       /usr/lib/R/library            3.6.3
# foreign        foreign        /usr/lib/R/library            0.8-76
# graphics       graphics       /usr/lib/R/library            3.6.3
# grDevices      grDevices      /usr/lib/R/library            3.6.3
# grid           grid           /usr/lib/R/library            3.6.3
# KernSmooth     KernSmooth     /usr/lib/R/library            2.23-17
# lattice        lattice        /usr/lib/R/library            0.20-41
# MASS           MASS           /usr/lib/R/library            7.3-53
# Matrix         Matrix         /usr/lib/R/library            1.2-18
# methods        methods        /usr/lib/R/library            3.6.3
# mgcv           mgcv           /usr/lib/R/library            1.8-33
# nlme           nlme           /usr/lib/R/library            3.1-149
# nnet           nnet           /usr/lib/R/library            7.3-14
# parallel       parallel       /usr/lib/R/library            3.6.3
# rpart          rpart          /usr/lib/R/library            4.1-15
# spatial        spatial        /usr/lib/R/library            7.3-12
# splines        splines        /usr/lib/R/library            3.6.3
# stats          stats          /usr/lib/R/library            3.6.3
# stats4         stats4         /usr/lib/R/library            3.6.3
# survival       survival       /usr/lib/R/library            3.2-3
# tcltk          tcltk          /usr/lib/R/library            3.6.3
# tools          tools          /usr/lib/R/library            3.6.3
# utils          utils          /usr/lib/R/library            3.6.3
#                Priority    Depends
# IRdisplay      NA          R (>= 3.0.1)
# IRkernel       NA          R (>= 3.2.0)
# palmerpenguins NA          R (>= 2.10)
# pbdZMQ         NA          R (>= 3.2.0)
# repr           NA          R (>= 3.0.1)
# uuid           NA          R (>= 2.9.0)
# askpass        NA          NA
# assertthat     NA          NA
# backports      NA          R (>= 3.0.0)
# base64enc      NA          R (>= 2.9.0)
# BH             NA          NA
# blob           NA          NA
# brew           NA          NA
# broom          NA          R (>= 3.1)
# callr          NA          NA
# cellranger     NA          R (>= 3.0.0)
# cli            NA          R (>= 2.10)
# clipr          NA          NA
# colorspace     NA          R (>= 3.0.0), methods
# commonmark     NA          NA
# covr           NA          R (>= 3.1.0), methods
# cpp11          NA          NA
# crayon         NA          NA
# crosstalk      NA          NA
# curl           NA          R (>= 3.0.0)
# DBI            NA          methods, R (>= 3.0.0)
# dbplyr         NA          R (>= 3.1)
# desc           NA          R (>= 3.1.0)
# devtools       NA          R (>= 3.0.2), usethis (>= 1.6.0)
# digest         NA          R (>= 3.1.0)
# ⋮              ⋮           ⋮
# yaml           NA          NA
# base           base        NA
# boot           recommended R (>= 3.0.0), graphics, stats
# class          recommended R (>= 3.0.0), stats, utils
# cluster        recommended R (>= 3.3.0)
# codetools      recommended R (>= 2.1)
# compiler       base        NA
# datasets       base        NA
# foreign        recommended R (>= 3.0.0)
# graphics       base        NA
# grDevices      base        NA
# grid           base        NA
# KernSmooth     recommended R (>= 2.5.0), stats
# lattice        recommended R (>= 3.0.0)
# MASS           recommended R (>= 3.1.0), grDevices, graphics, stats, utils
# Matrix         recommended R (>= 3.2.0)
# methods        base        NA
# mgcv           recommended R (>= 2.14.0), nlme (>= 3.1-64)
# nlme           recommended R (>= 3.4.0)
# nnet           recommended R (>= 3.0.0), stats, utils
# parallel       base        NA
# rpart          recommended R (>= 2.15.0), graphics, stats, grDevices
# spatial        recommended R (>= 3.0.0), graphics, stats, utils
# splines        base        NA
# stats          base        NA
# stats4         base        NA
# survival       recommended R (>= 3.4.0)
# tcltk          base        NA
# tools          base        NA
# utils          base        NA
#                Imports
# IRdisplay      methods, repr
# IRkernel       repr (>= 0.4.99), methods, evaluate (>= 0.10), IRdisplay (>=\n0.3.0.9999), pbdZMQ (>= 0.2-1), crayon, jsonlite (>= 0.9.6),\nuuid, digest
# palmerpenguins NA
# pbdZMQ         NA
# repr           utils, grDevices, htmltools, jsonlite, pillar (>= 1.4.0),\nbase64enc
# uuid           NA
# askpass        sys (>= 2.1)
# assertthat     tools
# backports      utils
# base64enc      NA
# BH             NA
# blob           methods, rlang, vctrs (>= 0.2.1)
# brew           NA
# broom          backports, dplyr, ellipsis, generics (>= 0.0.2), glue,\nmethods, purrr, rlang, stringr, tibble (>= 3.0.0), tidyr
# callr          processx (>= 3.4.0), R6, utils
# cellranger     rematch, tibble
# cli            assertthat, crayon (>= 1.3.4), glue, methods, utils, fansi
# clipr          utils
# colorspace     graphics, grDevices, stats
# commonmark     NA
# covr           digest, stats, utils, jsonlite, rex, httr, crayon, withr (>=\n1.0.2), yaml
# cpp11          NA
# crayon         grDevices, methods, utils
# crosstalk      htmltools (>= 0.3.6), jsonlite, lazyeval, R6
# curl           NA
# DBI            NA
# dbplyr         assertthat (>= 0.2.0), DBI (>= 1.0.0), dplyr (>= 0.8.0), glue\n(>= 1.2.0), lifecycle, magrittr, methods, purrr (>= 0.2.5), R6\n(>= 2.2.2), rlang (>= 0.2.0), tibble (>= 1.4.2), tidyselect (>=\n0.2.4), blob (>= 1.2.0), utils
# desc           assertthat, utils, R6, crayon, rprojroot
# devtools       callr (>= 3.4.3), cli (>= 2.0.2), covr (>= 3.5.0), desc (>=\n1.2.0), DT (>= 0.13), ellipsis (>= 0.3.0), httr (>= 1.4.1),\njsonlite (>= 1.6.1), memoise (>= 1.1.0), pkgbuild (>= 1.0.6),\npkgload (>= 1.0.2), rcmdcheck (>= 1.3.3), remotes (>= 2.2.0),\nrlang (>= 0.4.5), roxygen2 (>= 7.1.0), rstudioapi (>= 0.11),\nrversions (>= 2.0.1), sessioninfo (>= 1.1.1), stats, testthat\n(>= 2.3.2), tools, utils, withr (>= 2.1.2)
# digest         utils
# ⋮              ⋮
# yaml           NA
# base           NA
# boot           NA
# class          MASS
# cluster        graphics, grDevices, stats, utils
# codetools      NA
# compiler       NA
# datasets       NA
# foreign        methods, utils, stats
# graphics       grDevices
# grDevices      NA
# grid           grDevices, utils
# KernSmooth     NA
# lattice        grid, grDevices, graphics, stats, utils
# MASS           methods
# Matrix         methods, graphics, grid, stats, utils, lattice
# methods        utils, stats
# mgcv           methods, stats, graphics, Matrix, splines, utils
# nlme           graphics, stats, utils, lattice
# nnet           NA
# parallel       tools, compiler
# rpart          NA
# spatial        NA
# splines        graphics, stats
# stats          utils, grDevices, graphics
# stats4         graphics, methods, stats
# survival       graphics, Matrix, methods, splines, stats, utils
# tcltk          utils
# tools          NA
# utils          NA
#                LinkingTo
# IRdisplay      NA
# IRkernel       NA
# palmerpenguins NA
# pbdZMQ         NA
# repr           NA
# uuid           NA
# askpass        NA
# assertthat     NA
# backports      NA
# base64enc      NA
# BH             NA
# blob           NA
# brew           NA
# broom          NA
# callr          NA
# cellranger     NA
# cli            NA
# clipr          NA
# colorspace     NA
# commonmark     NA
# covr           NA
# cpp11          NA
# crayon         NA
# crosstalk      NA
# curl           NA
# DBI            NA
# dbplyr         NA
# desc           NA
# devtools       NA
# digest         NA
# ⋮              ⋮
# yaml           NA
# base           NA
# boot           NA
# class          NA
# cluster        NA
# codetools      NA
# compiler       NA
# datasets       NA
# foreign        NA
# graphics       NA
# grDevices      NA
# grid           NA
# KernSmooth     NA
# lattice        NA
# MASS           NA
# Matrix         NA
# methods        NA
# mgcv           NA
# nlme           NA
# nnet           NA
# parallel       NA
# rpart          NA
# spatial        NA
# splines        NA
# stats          NA
# stats4         NA
# survival       NA
# tcltk          NA
# tools          NA
# utils          NA
#                Suggests
# IRdisplay      testthat, withr
# IRkernel       testthat, roxygen2
# palmerpenguins knitr, rmarkdown, tibble, ggplot2, dplyr, tidyr, recipes
# pbdZMQ         NA
# repr           methods, highr, Cairo, stringr, testthat, diffobj (>= 0.2.3),\nleaflet
# uuid           NA
# askpass        testthat
# assertthat     testthat, covr
# backports      NA
# base64enc      NA
# BH             NA
# blob           covr, crayon, pillar (>= 1.2.1), testthat
# brew           NA
# ...
# survival       NA
# tcltk          NA
# tools          codetools, methods, xml2, curl, commonmark
# utils          methods, xml2, commonmark
#                Enhances
# IRdisplay      NA
# IRkernel       NA
# palmerpenguins NA
# pbdZMQ         NA
# repr           data.table, dplyr, htmlwidgets, vegalite, plotly, geojsonio
# uuid           NA
# askpass        NA
# assertthat     NA
# backports      NA
# base64enc      png
# BH             NA
# blob           NA
# brew           NA
# broom          NA
# callr          NA
# cellranger     NA
# cli            NA
# clipr          NA
# colorspace     NA
# commonmark     NA
# covr           NA
# cpp11          NA
# crayon         NA
# crosstalk      NA
# curl           NA
# DBI            NA
# dbplyr         NA
# desc           NA
# devtools       NA
# digest         NA
# ⋮              ⋮
# yaml           NA
# base           NA
# boot           NA
# class          NA
# cluster        NA
# codetools      NA
# compiler       NA
# datasets       NA
# foreign        NA
# graphics       NA
# grDevices      NA
# grid           NA
# KernSmooth     NA
# lattice        chron
# MASS           NA
# Matrix         MatrixModels, graph, SparseM, sfsmisc
# methods        NA
# mgcv           NA
# nlme           NA
# nnet           NA
# parallel       snow, nws, Rmpi
# rpart          NA
# spatial        NA
# splines        NA
# stats          NA
# stats4         NA
# survival       NA
# tcltk          NA
# tools          NA
# utils          NA
#                License                     License_is_FOSS
# IRdisplay      MIT + file LICENSE          NA
# IRkernel       MIT + file LICENSE          NA
# palmerpenguins CC0                         NA
# pbdZMQ         GPL-3                       NA
# repr           GPL-3                       NA
# uuid           MIT + file LICENSE          NA
# askpass        MIT + file LICENSE          NA
# assertthat     GPL-3                       NA
# backports      GPL-2 | GPL-3               NA
# base64enc      GPL-2 | GPL-3               NA
# BH             BSL-1.0                     NA
# blob           GPL-3                       NA
# brew           GPL-2                       NA
# broom          MIT + file LICENSE          NA
# callr          MIT + file LICENSE          NA
# cellranger     MIT + file LICENSE          NA
# cli            MIT + file LICENSE          NA
# clipr          GPL-3                       NA
# colorspace     BSD_3_clause + file LICENSE NA
# commonmark     BSD_2_clause + file LICENSE NA
# covr           GPL-3                       NA
# cpp11          MIT + file LICENSE          NA
# crayon         MIT + file LICENSE          NA
# crosstalk      MIT + file LICENSE          NA
# curl           MIT + file LICENSE          NA
# DBI            LGPL (>= 2.1)               NA
# dbplyr         MIT + file LICENSE          NA
# desc           MIT + file LICENSE          NA
# devtools       GPL (>= 2)                  NA
# digest         GPL (>= 2)                  NA
# ⋮              ⋮                           ⋮
# yaml           BSD_3_clause + file LICENSE NA
# base           Part of R 3.6.3             NA
# boot           Unlimited                   NA
# class          GPL-2 | GPL-3               NA
# cluster        GPL (>= 2)                  NA
# codetools      GPL                         NA
# compiler       Part of R 3.6.3             NA
# datasets       Part of R 3.6.3             NA
# foreign        GPL (>= 2)                  NA
# graphics       Part of R 3.6.3             NA
# grDevices      Part of R 3.6.3             NA
# grid           Part of R 3.6.3             NA
# KernSmooth     Unlimited                   NA
# lattice        GPL (>= 2)                  NA
# MASS           GPL-2 | GPL-3               NA
# Matrix         GPL (>= 2) | file LICENCE   NA
# methods        Part of R 3.6.3             NA
# mgcv           GPL (>= 2)                  NA
# nlme           GPL (>= 2) | file LICENCE   NA
# nnet           GPL-2 | GPL-3               NA
# parallel       Part of R 3.6.3             NA
# rpart          GPL-2 | GPL-3               NA
# spatial        GPL-2 | GPL-3               NA
# splines        Part of R 3.6.3             NA
# stats          Part of R 3.6.3             NA
# stats4         Part of R 3.6.3             NA
# survival       LGPL (>= 2)                 NA
# tcltk          Part of R 3.6.3             NA
# tools          Part of R 3.6.3             NA
# utils          Part of R 3.6.3             NA
#                License_restricts_use OS_type MD5sum NeedsCompilation Built
# IRdisplay      NA                    NA      NA     no               3.6.3
# IRkernel       NA                    NA      NA     no               3.6.3
# palmerpenguins NA                    NA      NA     no               3.6.3
# pbdZMQ         NA                    NA      NA     yes              3.6.3
# repr           NA                    NA      NA     no               3.6.3
# uuid           NA                    NA      NA     yes              3.6.3
# askpass        NA                    NA      NA     yes              3.5.2
# assertthat     NA                    NA      NA     no               3.5.3
# backports      NA                    NA      NA     yes              3.6.3
# base64enc      NA                    NA      NA     yes              3.5.0
# BH             NA                    NA      NA     no               3.6.2
# blob           NA                    NA      NA     no               3.6.2
# brew           NA                    NA      NA     NA               3.5.0
# broom          NA                    NA      NA     no               3.6.3
# callr          NA                    NA      NA     no               3.6.3
# cellranger     NA                    NA      NA     no               3.5.0
# cli            NA                    NA      NA     no               3.6.3
# clipr          NA                    NA      NA     no               3.6.1
# colorspace     NA                    NA      NA     yes              3.5.3
# commonmark     NA                    NA      NA     yes              3.5.1
# covr           NA                    NA      NA     yes              3.6.3
# cpp11          NA                    NA      NA     no               3.6.3
# crayon         NA                    NA      NA     no               3.5.0
# crosstalk      NA                    NA      NA     no               3.6.3
# curl           NA                    NA      NA     yes              3.6.1
# DBI            NA                    NA      NA     no               3.6.2
# dbplyr         NA                    NA      NA     no               3.6.3
# desc           NA                    NA      NA     no               3.5.0
# devtools       NA                    NA      NA     no               3.6.3
# digest         NA                    NA      NA     yes              3.6.3
# ⋮              ⋮                     ⋮       ⋮      ⋮                ⋮
# yaml           NA                    NA      NA     yes              3.6.2
# base           NA                    NA      NA     NA               3.6.3
# boot           NA                    NA      NA     no               3.6.3
# class          NA                    NA      NA     yes              3.6.3
# cluster        NA                    NA      NA     yes              3.6.1
# codetools      NA                    NA      NA     no               3.6.3
# compiler       NA                    NA      NA     NA               3.6.3
# datasets       NA                    NA      NA     NA               3.6.3
# foreign        NA                    NA      NA     yes              3.6.3
# graphics       NA                    NA      NA     yes              3.6.3
# grDevices      NA                    NA      NA     yes              3.6.3
# grid           NA                    NA      NA     yes              3.6.3
# KernSmooth     NA                    NA      NA     yes              3.6.3
# lattice        NA                    NA      NA     yes              3.6.3
# MASS           NA                    NA      NA     yes              3.6.3
# Matrix         NA                    NA      NA     yes              3.6.1
# methods        NA                    NA      NA     yes              3.6.3
# mgcv           NA                    NA      NA     yes              3.6.3
# nlme           NA                    NA      NA     yes              3.6.3
# nnet           NA                    NA      NA     yes              3.6.3
# parallel       NA                    NA      NA     yes              3.6.3
# rpart          NA                    NA      NA     yes              3.6.1
# spatial        NA                    NA      NA     yes              3.6.3
# splines        NA                    NA      NA     yes              3.6.3
# stats          NA                    NA      NA     yes              3.6.3
# stats4         NA                    NA      NA     NA               3.6.3
# survival       NA                    NA      NA     yes              3.6.3
# tcltk          NA                    NA      NA     yes              3.6.3
# tools          NA                    NA      NA     yes              3.6.3
# utils          NA                    NA      NA     yes              3.6.3

# %%
library(tidyverse)

# %%
install.packages("palmerpenguins")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(palmerpenguins)

# %%
penguins %>%
  count(species) %>%
  ggplot() + geom_col(aes(x = species, y = n, fill = species)) +
  geom_label(aes(x = species, y = n, label = n)) +
  scale_fill_manual(values = c("darkorange","purple","cyan4")) +
  theme_minimal() +
  labs(title = 'Penguins Species & Count')
# Out:
# plot without title
