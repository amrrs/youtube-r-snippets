# %%
# Courtesy: Michael Beyeler
#  How to create a beautiful pencil sketch effect with OpenCV and Python  https://www.askaswiss.com/2016/01/how-to-create-pencil-sketch-opencv-python.html

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("virat_kohli.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F36299D35F8>

# %%
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=260x260 at 0x7F362999C6A0>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=260x260 at 0x7F362992A5F8>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=260x260 at 0x7F362992A240>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=260x260 at 0x7F362992A710>

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=260x260 at 0x7F36298D0780>
